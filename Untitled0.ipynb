# %%
from google.cloud import bigquery

# %% [markdown]
# The first step in the workflow is to create a Client object. As you'll soon see, this Client object will play a central role in retrieving information from BigQuery datasets.

# %%
client= bigquery.Client()

# %% [markdown]
# We begin by constructing a reference to the dataset with the ** dataset()** method.
# Next, we use the ** get_dataset()** method, along with the reference we just constructed, to fetch the dataset.\

# %%
#führe Folgendes aus, um dich zu authentifizieren
from google.colab import auth
auth.authenticate_user()

from google.cloud import bigquery
client = bigquery.Client()

# %%
#Construct a reference to the "hacker_news" dataset
dataset_ref= client.dataset("hacker_news",project="bigquery-public-data")
# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %%
# List all the tables in the "hacker_news" dataset
tables= list(client.list_tables(dataset))

tables

# %%
# Print names of all tables in the dataset (there are four!)
for table in tables:
    print(table.table_id)
# Out:
# full

# %%
# Construct a reference to the "full" table
table_ref= dataset_ref.table("full")
# API request - fetch the table
table=client.get_table(table_ref)

# %%
table.schema
# Out:
# [SchemaField('title', 'STRING', 'NULLABLE', None, 'Story title', (), None),
#  SchemaField('url', 'STRING', 'NULLABLE', None, 'Story url', (), None),
#  SchemaField('text', 'STRING', 'NULLABLE', None, 'Story or comment text', (), None),
#  SchemaField('dead', 'BOOLEAN', 'NULLABLE', None, 'Is dead?', (), None),
#  SchemaField('by', 'STRING', 'NULLABLE', None, "The username of the item's author.", (), None),
#  SchemaField('score', 'INTEGER', 'NULLABLE', None, 'Story score', (), None),
#  SchemaField('time', 'INTEGER', 'NULLABLE', None, 'Unix time', (), None),
#  SchemaField('timestamp', 'TIMESTAMP', 'NULLABLE', None, 'Timestamp for the unix time', (), None),
#  SchemaField('type', 'STRING', 'NULLABLE', None, 'type of details (comment comment_ranking poll story job pollopt)', (), None),
#  SchemaField('id', 'INTEGER', 'NULLABLE', None, "The item's unique id.", (), None),
#  SchemaField('parent', 'INTEGER', 'NULLABLE', None, 'Parent comment ID', (), None),
# ...

# %% [markdown]
# The mode of the column ('NULLABLE' means that a column allows NULL values, and is the default)
#
# We can use the **list_row**s() method to check just the first five lines of of the full table to make sure this is right. (Sometimes databases have outdated descriptions, so it's good to check.) This returns a BigQuery RowIterator object that can quickly be converted to a pandas DataFrame with the to_dataframe() method.

# %%
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#   title   url  text  dead    by  score        time                 timestamp  \
# 0  None  None  None  <NA>  None   <NA>  1437596602 2015-07-22 20:23:22+00:00
# 1  None  None  None  <NA>  None   <NA>  1437596643 2015-07-22 20:24:03+00:00
# 2  None  None  None  <NA>  None   <NA>  1437599935 2015-07-22 21:18:55+00:00
# 3  None  None  None  <NA>  None   <NA>  1437599989 2015-07-22 21:19:49+00:00
# 4  None  None  None  <NA>  None   <NA>  1437600528 2015-07-22 21:28:48+00:00
#
#     type       id  parent  descendants  ranking  deleted
# 0  story  9932058    <NA>         <NA>     <NA>     <NA>
# 1  story  9932066    <NA>         <NA>     <NA>     <NA>
# 2  story  9932359    <NA>         <NA>     <NA>     <NA>
# 3  story  9932362    <NA>         <NA>     <NA>     <NA>
# 4  story  9932423    <NA>         <NA>     <NA>     <NA>

# %%
# Preview the first five entries in the "title, url" column of the "full" table
client.list_rows(table, selected_fields=table.schema[:2], max_results=5).to_dataframe()
# Out:
#   title   url
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None

# %% [markdown]
# 1) Count tables in the dataset
# How many tables are in the Chicago Crime dataset?

# %%
# Write the code you need here to figure out the answer
table= list(client.list_tables(dataset))

for tables in table:
     print(len(table))
# Out:
# 1

# %% [markdown]
# 2) Explore the table schema¶
# How many columns in the crime table have TIMESTAMP data?

# %%
# Write the code to figure out the answer
table_ref = dataset_ref.table("full")
table= client.get_table(table_ref)
timestam_columns = [field for field in table.schema if field.field_type == "TIMESTAMP"]
print(len(timestam_columns))
# Out:
# 1

# %% [markdown]
# 3) Create a crime map
# If you wanted to create a map with a dot at the location of each crime, what are the names of the two fields you likely need to pull out of the crime table to plot the crimes on a map?

# %%
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#   title   url  text  dead    by  score        time                 timestamp  \
# 0  None  None  None  <NA>  None   <NA>  1437596602 2015-07-22 20:23:22+00:00
# 1  None  None  None  <NA>  None   <NA>  1437596643 2015-07-22 20:24:03+00:00
# 2  None  None  None  <NA>  None   <NA>  1437599935 2015-07-22 21:18:55+00:00
# 3  None  None  None  <NA>  None   <NA>  1437599989 2015-07-22 21:19:49+00:00
# 4  None  None  None  <NA>  None   <NA>  1437600528 2015-07-22 21:28:48+00:00
#
#     type       id  parent  descendants  ranking  deleted
# 0  story  9932058    <NA>         <NA>     <NA>     <NA>
# 1  story  9932066    <NA>         <NA>     <NA>     <NA>
# 2  story  9932359    <NA>         <NA>     <NA>     <NA>
# 3  story  9932362    <NA>         <NA>     <NA>     <NA>
# 4  story  9932423    <NA>         <NA>     <NA>     <NA>

# %%
fields_for_plotting = ['latitude','longitude'] # Put your answers here
